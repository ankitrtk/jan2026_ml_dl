# %%
amount = 10.4
years = 12
rate = 1.34
name = "Sandeep Giri" 
arr = [1,2,3,4]

# %%
mylist = [3,4,5]
mylist[0]
# Out:
# 3

# %%
mylist[0] = 30
print(mylist)
# Out:
# [30, 4, 5]

# %%
name[0] = 'M'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 name[0] = 'M'
#
# TypeError: 'str' object does not support item assignment

# %%
location = (1, 3)

# %%
location[1]
# Out:
# 3

# %%
type(location), type(name), type(mylist)
# Out:
# (tuple, str, list)

# %%
name = "Sandeep Giri"
name1 = 'Sandeep Giri'
name2 = '''Sandeep Giri'''

# %%
name == name1
# Out:
# True

# %%
name == name2
# Out:
# True

# %%
"Des'Carte"
# Out:
# "Des'Carte"

# %%
print("De\'cart & L\"Hospitals ")
# Out:
# De'cart & L"Hospitals

# %%
print("This is a slash: \\")
# Out:
# This is a slash: \

# %%
# This is a comment
'''
This is the documentation of my workd.
please use it responsibily
'''
# Out:
# '\nThis is the documentation of my workd.\nplease use it responsibily\n'

# %%
def interest(p, r, t):
    return p*r*t/100
print("ABC")
# Out:
# ABC

# %%
does_work = True
print(does_work)
# Out:
# True

# %%
def interest1(p, r, t):
    print(p*r*t/100)
    #print("ABC")

# %%
myint = interest1(1000, 12, 5)
print("Calculated Interest is: ", myint)
# Out:
# 600.0
# Calculated Interest is:  None

# %%
interest(10, 1, 40)
# Out:
# 4.0
# ABC

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>

# %% [markdown]
# - int
# - number / float / long
# - bool
# - list
# - tuple
# - NoneType
# - Function
# - Complex Datatype: dict, set, ...

# %%
type(interest)
# Out:
# function

# %%
myint2 = interest

# %%
myint2(10, 2, 3)
# Out:
# 0.6

# %%
_ = 100
print(_)
# Out:
# 100

# %%
#1x = 100 - invalid
x1 = 100

# %%
def order_data(x, y):
    if x > y:
        return y, x
    return x, y

# %%
order_data(5, 4)
# Out:
# (4, 5)

# %%
order_data(10, 30)
# Out:
# (10, 30)

# %%
x = (1)
type(x)
# Out:
# int

# %%
x = 1,
print(type(x))
# Out:
# <class 'tuple'>

# %%
x = 1,2,3,4
print(type(x))
# Out:
# <class 'tuple'>

# %%
def print_age_group(age):
    if age <= 1:
        print("Infant")
    elif age < 13:
        print("Kid")
    elif age < 20:
        print("Teen")
    else:
        print("Adult")

# %%
print_age_group(0.5)
# Out:
# Infant

# %%
print_age_group(1.5)
# Out:
# Kid

# %% [markdown]
# Recursion - A function calling itself

# %% [markdown]
# # Calculate power
# 2**3 = 2 * 2 * 2
#
# 2**0 = 1
#
# x ** y
#
# Definition1 - x * x * x *x ... y times
# Definition2 - 1 * (x * x * x .... y times)
#
#
# 0 ** 2 = 0
# 0 ** 1 = 0
# 0 ** 0 = 1

# %%
0 ** 0
# Out:
# 1

# %%
# Calculate x to power y
def mypower(x, y): # y is a positive integer
    # x ** 3 -> x * x ** 2 -> x * x * x ** 1 -> x * x * x * x ** 0
    if ....
        return 1
    else:
        return mypower(x, y - 1)
