# %% [markdown]
# # log(125)
#
# guess = 3
# 10^3

# %%
guess = 3
10**guess
# Out:
# 1000

# %%
# 10**guess = 125

guess = .5
10**guess
# Out:
# 3.1622776601683795

# %%
# 10**guess = 125

guess = 2
10**guess
# Out:
# 100

# %%
guess = 2.5
10**guess
# Out:
# 316.22776601683796

# %%
left = 2
right = 2.5
guess = (left + right)/2
guess, 10**guess
# Out:
# (2.25, 177.82794100389228)

# %%
left = 2
right = 2.25
guess = (left + right)/2
guess, 10**guess
# Out:
# (2.125, 133.3521432163324)

# %%
right = guess 

guess = (left + right)/2
guess, 10**guess
# Out:
# (2.0625, 115.47819846894582)

# %%
left = guess

guess = (left + right)/2
guess, 10**guess
# Out:
# (2.09375, 124.09377607517196)

# %%
left = guess

guess = (left + right)/2
guess, 10**guess
# Out:
# (2.109375, 128.63969449369745)

# %%
right = guess

guess = (left + right)/2
guess, 10**guess
# Out:
# (2.1015625, 126.34629176544685)

# %%
right = guess

guess = (left + right)/2
guess, 10**guess
# Out:
# (2.09765625, 125.21496890655567)

# %%
import math
math.log10(125)
# Out:
# 2.0969100130080562

# %%
# Calculate sqrt
#sqrt(20)
guess = 5
guess ** 2
# Out:
# 25

# %%
left = 4
right = 5
guess = (left + right)/2
...

# %%
# cube root

#cuberoot of 50
guess = 5
guess ** 3
# Out:
# 125

# %%
guess = 3.5
guess**3
# Out:
# 42.875

# %%
left = 3.5
right = 5
guess = (left + right)/2
guess, guess ** 3
# Out:
# (4.25, 76.765625)

# %%
left = 3.5
right = 4.25
guess = (left + right)/2
guess, guess ** 3
# Out:
# (3.875, 58.185546875)

# %%
left = 3.5
right = 3.875
guess = (left + right)/2
guess, guess ** 3
# Out:
# (3.6875, 50.141357421875)

# %%
# Try sqrt, cuberoot, log, number guess
# Binary Search
