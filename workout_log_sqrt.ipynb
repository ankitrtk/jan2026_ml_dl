# %%
import math

# %%
math.log10(10)
# Out:
# 1.0

# %%
math.log10(20)
# Out:
# 1.3010299956639813

# %%
10**1.3010299956639813
# Out:
# 20.000000000000004

# %%
# what is log10(56)
ans = 1.6
10**ans
# Out:
# 39.810717055349734

# %%
ans = 1.8
10**ans
# Out:
# 63.09573444801933

# %%
ans = 1.73
10**ans
# Out:
# 53.70317963702527

# %%
ans = 1.75
10**ans
# Out:
# 56.23413251903491

# %%
ans = 1.748
10**ans
# Out:
# 55.97576014951102

# %%
ans = 1.749
10**ans
# Out:
# 56.104797603247064

# %%
ans = 1.7489
10**ans
# Out:
# 56.09188048338182

# %%
10**2
# Out:
# 100

# %%
math.log10(100)
# Out:
# 2.0

# %%
# 80
def try_guess(left, right):
    guess = (left + right)/2
    print(guess, guess*guess)

# %%
try_guess(6, 10)
# Out:
# 8.0 64.0

# %%
try_guess(8, 10)
# Out:
# 9.0 81.0

# %%
try_guess(8, 9)
# Out:
# 8.5 72.25

# %%
try_guess(8.5, 9)
# Out:
# 8.75 76.5625

# %%
try_guess(8.75, 9)
# Out:
# 8.875 78.765625

# %%
try_guess(8.875, 9)
# Out:
# 8.9375 79.87890625

# %%
try_guess(8.9375, 9)
# Out:
# 8.96875 80.4384765625

# %%
try_guess(8.9375, 8.96875)
# Out:
# 8.953125 80.158447265625

# %%
try_guess(8.9375, 8.953125)
# Out:
# 8.9453125 80.01861572265625

# %%
try_guess(8.9375, 8.9453125)
# Out:
# 8.94140625 79.94874572753906

# %%
try_guess(8.94140625, 8.9453125)
# Out:
# 8.943359375 79.98367691040039

# %%
try_guess(8.943359375, 8.9453125)
# Out:
# 8.9443359375 80.001145362854

# %%
try_guess(8.943359375, 8.9443359375)
# Out:
# 8.94384765625 79.99241089820862

# %%
try_guess(8.94384765625, 8.9443359375)
# Out:
# 8.944091796875 79.99677807092667

# %%
try_guess(8.944091796875, 8.9443359375)
# Out:
# 8.9442138671875 79.99896170198917

# %%
try_guess(8.9442138671875, 8.9443359375)
# Out:
# 8.94427490234375 80.0000535286963

# %%
80**.5
# Out:
# 8.94427190999916
