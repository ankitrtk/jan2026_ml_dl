# %%
import pandas as pd

df = pd.read_csv('movies_ratings.csv')

# %%
df = df.drop(columns=['Yukta','Priya', 'Harshita'])

# %%
df
# Out:
#                     Movies_Name  SandeepGiri  Abhishek  Gurkaran  Madhuri  \
# 0                       Titanic          4.0       2.0       4.0     5.00
# 1                        Matrix          4.8       1.0       3.0     5.00
# 2                  Jurasic Park          4.2       2.0       4.0     4.00
# 3                        Sholay          4.0       5.0       4.0     4.00
# 4   Dilwale Dulhania Le Jayenge          3.8       5.0       4.0     2.00
# 5                 Mughal-e-Azam          NaN       2.0       2.0     5.00
# 6                       Deewaar          NaN       4.0       2.0     2.00
# 7            Amar Akbar Anthony          NaN       5.0       2.0     2.00
# 8                        Lagaan          4.0       5.0       3.0     4.00
# 9      Kabhi Khushi Kabhie Gham          3.8       4.0       3.0     2.00
# 10                Kal Ho Naa Ho          3.8       3.0       3.0     2.00
# 11                     3 Idiots          4.0       5.0       4.0     4.50
# ...

# %% [markdown]
# # Primary Objective
#
# 1. Find similar people -  cross recommendation - People like you have like these movies too.
# 2. Find similar movies - People who like this movie also like that movie.

# %%
import numpy as np
arr = np.array([3, 3.1 , 4.2, 4.5])

# %%
# Q: Some people are more generous in giving rating and other are stringy ??
# min-max Scaling
[3, 3, 4, 4, 4, 3.5]
-> [0, 0, 1, 1, 1, .5]

def min_max_scaling(np_arr):
    # find the min and max
    # subtract each value with min making all value to between 0 and max-min
    # convert it into [0, 1] by dividing by max-min

# %%
# Exercise 1
# Scale each persons rating to between 0 and 1
# take a column, drop missing values and then scale the values and update the df

# %%
# Q: What should we do with NaN

# 1. fill it with zero - it might get confused with the movies with actual rating 0
# 2. Ignore the cell - ignore row or ignore the column
# 3. ignore row - we lose info
# 4. ignore the column - we lose info
# 5. Imputation - Mode, AVG or Median
# 6. Decision Tree based imputation - filling

# [A, A, A, B, B , C, C, C, C, D] -> Mode : C 
# AVG - of row
# Median - sort the data - find the middle point, avg(p1, p2)

# %%
# For each row, compute the average ignoring missing values. and update the missing values with the avg

# %%
# compute the similarity between people
# Take each column and convert it into unit vector
# [3, 4] -> [3/5, 4/5] # Divide the vector by its norm

# Figure out who are closest 2 persons to each person and give the cross recommendation to each other.
# prepare the recommendation: moviename, average of the two.

# %%
# How do I find similarity between people

peopl1 = [.3, .4]
people2 = [.05, .12]
people3 = [.4, .3]

# Two ways: L2 other cosine

Cosine is easier:
1. You can utilize matrix multiplication for lots of vector 
2. Cosing is faster
But we need to convert each vector into unit vectors.

# o(n^2)

# %%
# Why convert to unit vector??

# %%
# Given a set of vectors convert them into unit vectors.

# %%
import numpy as np 
arr = np.array([[3,4], [5, 12]])

# arr / np.sqrt(np.sum(arr**2, axis=1))

# %%
arr/np.sqrt(np.sum(arr**2, axis=1)).reshape(2, 1)
# Out:
# array([[0.6       , 0.8       ],
#        [0.38461538, 0.92307692]])

# %%
arr/np.sqrt(np.sum(arr**2, axis=1)).reshape(1, 2) # WRONG
# Out:
# array([[0.6       , 0.30769231],
#        [1.        , 0.92307692]])

# %%
# Matrix will be in this format

#SandeepGiri, Matrix, 4.8
#SandeepGiri, Titanic, 4

# Exercise
# Using MapReduce - do the matrix multiplication
# Each matrix is give in the columnar format:

file1:
i, j, value
0, 0, .1
0, 1, .2
1, 0, ... 

file2:
i, j, value

file1 @ file2
