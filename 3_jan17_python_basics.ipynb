# %%
1234 % 10
# Out:
# 4

# %%
1234 % 10

# %% [markdown]
# # Use cases of %
#
# 1. Divisibility Checks
# 2. Extracting last digit
# 3. Converting into smaller -> hashcode, load balancing, creating buckets, circular lists
# 4. One way encryption

# %% [markdown]
# #You have numbers from 0 to a billions - userid
#
# You want to put them or shard them into 35 servers.
# user id -> 0 to 34
# user_id % 35

# %%
def convert_to_bucket(user_id):
    return user_id % 35

# %%
convert_to_bucket(5678)
# Out:
# 8

# %%
ord('A'), ord('B'), ord('C'), ord('D')
# Out:
# (65, 66, 67, 68)

# %%
ord('a'), ord('b'), ord('c'), ord('z')
# Out:
# (97, 98, 99, 122)

# %%
chr(97)
# Out:
# 'a'

# %%
chr(2350), chr(2351), chr(2352)
# Out:
# ('म', 'य', 'र')

# %%
ord('य')
# Out:
# 2351

# %%
#"giri" -> integer between 0 and 500

ord('g'), ord('i'), ord('r'), ord('i')
# Out:
# (103, 105, 114, 105)

# %%
sum([103, 105, 114, 105]) % 500 #isla
# Out:
# 427

# %%
sum([103, 64*105, 64*64*114, 64*64*64*105]) % 500 #inder
#Q: Discover and read the code of 'hash' method of python.
# Out:
# 387

# %%
hash('giri')
# Out:
# -7961010818900928392

# %%
# 35 % 35 -> 0
# 70 % 35 -> 0

# One way encryption

# %%
345 % 10
# Out:
# 5

# %%
123 // 10
# Out:
# 12

# %%
num = 1234

# %%
print(num)
lastdigit = num % 10
print(lastdigit)
num = num // 10
# Out:
# 1234
# 4

# %%
print(num)
lastdigit = num % 10
print(lastdigit)
num = num // 10
# Out:
# 123
# 3

# %%
print(num)
lastdigit = num % 10
print(lastdigit)
num = num // 10
# Out:
# 12
# 2

# %%
print(num)
lastdigit = num % 10
print(lastdigit)
num = num // 10
# Out:
# 1
# 1
