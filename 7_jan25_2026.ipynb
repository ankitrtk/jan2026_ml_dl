# %%
def solve(eqns):
    if len(eqns) == 1:
        a, b = eqns[0]
        return a/b
    else:
        print("Not yet implemented")
        return None

# %%
eqns = [[5, 2]]
len(eqns)
# Out:
# 1

# %%
a, b = eqns[0]
a/b
# Out:
# 2.5

# %% [raw]
# def solve(Eqns):
#     # returns an array of solutions
#
# >> Solve([[5, 2]])
# [2.5] 5 = 2x
#
#     >> Solve([
#     [5, 2, 1],
#     [7, 1, -1]
#     )
# [4, -3]
# 5 = 2x + y
# 7 = x - y
#
# >> Solve([[1, 1, -1, 1], [2, 1, 1, -1], [0, 1, -1, -1]])
# [1.5, 1, 0.5]
# 1 = a - b + c
# 2 = a + b - c
# 0 = a -b - c

# %%
eqns = [[5, 2]] # 5 = 2x
solve(eqns)
# Out:
# 2.5

# %%
a = [5, 2]
print(a[0]/a[1]) # 5/2
# Out:
# 2.5

# %%
a, b = [5, 2]
print(a / b)
# Out:
# 2.5

# %%
my_list = ["Sandeep", 2.3, 1, 2 == 3, [5,6], (5,6,7)]
l = my_list

# %%
my_list
# Out:
# ['Sandeep', 2.3, 1, False, [5, 6], (5, 6, 7)]

# %%
l
# Out:
# ['Sandeep', 2.3, 1, False, [5, 6], (5, 6, 7)]

# %%
for e in l:
    print(e, type(e))
# Out:
# Sandeep <class 'str'>
# 2.3 <class 'float'>
# 1 <class 'int'>
# False <class 'bool'>
# [5, 6] <class 'list'>
# (5, 6, 7) <class 'tuple'>

# %%
l[2] = 100

# %%
l
# Out:
# ['Sandeep', 2.3, 100, False, [5, 6], (5, 6, 7)]

# %%
my_list
# Out:
# ['Sandeep', 2.3, 100, False, [5, 6], (5, 6, 7)]

# %%
my_list[4][0] = 50

# %%
my_list[4]
# Out:
# [50, 6]

# %%
my_list
# Out:
# ['Sandeep', 2.3, 100, False, [50, 6], (5, 6, 7)]

# %%
e = my_list[4]

# %%
e
# Out:
# [50, 6]

# %%
my_list[4][0] = 500

# %%
e
# Out:
# [500, 6]

# %%
my_list[4] = [67, 6]

# %%
e
# Out:
# [500, 6]

# %%
e = [50, 6]
my_list = ['Sandeep', 2.3, 100, False, e, (5, 6, 7)]
my_list
# Out:
# ['Sandeep', 2.3, 100, False, [50, 6], (5, 6, 7)]

# %%
my_list[4] = [6,7]

# %%
my_list
# Out:
# ['Sandeep', 2.3, 100, False, [6, 7], (5, 6, 7)]

# %%
e
# Out:
# [50, 6]

# %%
x = 10
y = 20
tmp = x
x = y
y = tmp
x, y
# Out:
# (20, 10)

# %%
x = 10
y = 20
x, y = y, x
x, y
# Out:
# (20, 10)

# %%
# without tmp
x, y = 10, 20
x = x*y
y = x / y
x = x / y
x, y
# Out:
# (20.0, 10.0)

# %%
x, y = 10, 0
x = x*y
y = x / y
x = x / y
x, y
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[47], line 3
#       1 x, y = 10, 0
#       2 x = x*y
# ----> 3 y = x / y
#       4 x = x / y
#       5 x, y
#
# ZeroDivisionError: division by zero

# %%
X, Y = -5.5, -4
X = X + Y # 9, 4
Y = X - Y # 9, 5
X = X - Y # 4, 5
X, Y
# Out:
# (-4.0, -5.5)

# %%
# Overflow is a problem - binary search Java had the same bug in 2012 --
# Take bigger data type
# Divide by 10, take log
# XOR

# %% [raw]
# # Binary Numbers
# 0
# 1
# 10
# 11
# 100
# 101
# 110
# 111
# 1000

# %% [raw]
# 11 + 1 = 100
# 10 + 1 = 11

# %%
0b10 | 0b11
# Out:
# 3

# %%
bin(7)
# Out:
# '0b111'

# %%
bin(0b1010 | 0b1001)
# Out:
# '0b1011'

# %%
0b1010
# Out:
# 10

# %%
0b1001
# Out:
# 9

# %%
10 | 9
# Out:
# 11

# %%
bin(11)
# Out:
# '0b1011'

# %%
10 & 9
# Out:
# 8

# %%
bin(8)
# Out:
# '0b1000'

# %%
bin(~0b1011)
# Out:
# '-0b1100'

# %%
# XOR

0 ^ 0, 0 ^ 1, 1 ^ 0 , 1 ^ 1
# Out:
# (0, 1, 1, 0)

# %%
bin(0b1010 ^ 0b1001)
# Out:
# '0b11'

# %%
56 ^ 78
# Out:
# 118

# %%
118 ^ 78
# Out:
# 56

# %%
118 ^ 56
# Out:
# 78

# %%
# XOR for backup - RAID5
# XOR for tmp variable

x, y = 10, 45
x = x ^ y
y = x ^ y
x = x ^ y
x, y
# Out:
# (45, 10)

# %%
# XOR two light switch -> flipping any of two switches

# Using XOR -> half adder

# As a test case for complex relationships in input
# Capturing a XOR relationship is fair hard 

# Player1, Player2, ....10 players. - Win / lose
# p1 + p2 -> lose
# both are missing then also we lose

# Such XOR kind of relationship is very dificult
# y = m * x1 + m1*x2 + c

# %%
# See https://nandgame.com/
# Minecraft videos on how to create minecraft in minecraft

# %%
def divide(x, y):
    if x < y:
        return 0, x
    else:
        # pass

# %%
divide(3, 4)
# Out:
# (0, 3)

# %%
divide(58, 4)
# Out:
# (14, 2)

# %%
# Recursion
# 1. Playing a game -> Deep Q Learn -> Recursion
# 2. RNN

# %%
# https://www.youtube.com/watch?v=rf6uf3jNjbo

# %%
# Mathematical Induction -> https://en.wikipedia.org/wiki/Mathematical_induction
